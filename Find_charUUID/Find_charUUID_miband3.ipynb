# %%
import asyncio # 비동기화 모듈
from bleak import BleakScanner # BLE 검색 모듈
import nest_asyncio
nest_asyncio.apply()

# %%
# 비동기 형태로 BLE 장치 검색

async def runna():
    # 검색 시작 (검색이 종료될때까지 대기)
    # 기본 검색 시간은 5초이다.
    devices = await BleakScanner.discover()
    # 검색된 장치들 리스트 출력
    for d in devices:
        print(d)

# 비동기 이벤트 루프 생성
loop = asyncio.get_event_loop()
# 비동기 형태로 run(검색)함수 실행
# 완료될때까지 대기
loop.run_until_complete(runna())
# Out:
# 69:E7:26:83:E5:4B: Apple, Inc. (b'\x10\x06\x1c\x19\xc4S\xe5\x08')
# 73:60:A5:3F:12:31: Apple, Inc. (b'\x10\x07\t\x1b\x88=q\x0c\x18')
# DB:15:C2:8A:93:DF: Mi Band 3

# %%
import asyncio
from bleak import BleakClient

address = "DB:15:C2:8A:93:DF"
async def run(address):    
    async with BleakClient(address) as client:
        print('connected')
        services = await client.get_services()        
        for service in services:
            print(service)             
            # 서비스의 UUID 출력   
            print('\tuuid:', service.uuid)
            print('\tcharacteristic list:')
            # 서비스의 모든 캐릭터리스틱 출력용
            for characteristic in service.characteristics:
                # 캐릭터리스틱 클래스 변수 전체 출력
                print('\t\t', characteristic)
                # UUID 
                print('\t\tuuid:', characteristic.uuid)
                # decription(캐릭터리스틱 설명)
                print('\t\tdescription :', characteristic.description)
                # 캐릭터리스틱의 속성 출력
                # 속성 값 : ['write-without-response', 'write', 'read', 'notify']
                print('\t\tproperties :', characteristic.properties)

    print('disconnect')

loop = asyncio.get_event_loop()
loop.run_until_complete(run(address))
print('done')
# Out:
# connected
# 00001800-0000-1000-8000-00805f9b34fb (Handle: 1): Generic Access Profile
# 	uuid: 00001800-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a00-0000-1000-8000-00805f9b34fb (Handle: 2): Device Name
# 		uuid: 00002a00-0000-1000-8000-00805f9b34fb
# 		description : Device Name
# 		properties : ['read']
# 		 00002a01-0000-1000-8000-00805f9b34fb (Handle: 4): Appearance
# 		uuid: 00002a01-0000-1000-8000-00805f9b34fb
# 		description : Appearance
# 		properties : ['read']
# 		 00002a04-0000-1000-8000-00805f9b34fb (Handle: 6): Peripheral Preferred Connection Parameters
# 		uuid: 00002a04-0000-1000-8000-00805f9b34fb
# 		description : Peripheral Preferred Connection Parameters
# 		properties : ['read']
# 00001801-0000-1000-8000-00805f9b34fb (Handle: 8): Generic Attribute Profile
# 	uuid: 00001801-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a05-0000-1000-8000-00805f9b34fb (Handle: 9): Service Changed
# 		uuid: 00002a05-0000-1000-8000-00805f9b34fb
# 		description : Service Changed
# 		properties : ['read', 'indicate']
# 0000180a-0000-1000-8000-00805f9b34fb (Handle: 12): Device Information
# 	uuid: 0000180a-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a25-0000-1000-8000-00805f9b34fb (Handle: 13): Serial Number String
# 		uuid: 00002a25-0000-1000-8000-00805f9b34fb
# 		description : Serial Number String
# 		properties : ['read']
# 		 00002a27-0000-1000-8000-00805f9b34fb (Handle: 15): Hardware Revision String
# 		uuid: 00002a27-0000-1000-8000-00805f9b34fb
# 		description : Hardware Revision String
# 		properties : ['read']
# 		 00002a28-0000-1000-8000-00805f9b34fb (Handle: 17): Software Revision String
# 		uuid: 00002a28-0000-1000-8000-00805f9b34fb
# 		description : Software Revision String
# 		properties : ['read']
# 		 00002a23-0000-1000-8000-00805f9b34fb (Handle: 19): System ID
# 		uuid: 00002a23-0000-1000-8000-00805f9b34fb
# 		description : System ID
# 		properties : ['read']
# 		 00002a50-0000-1000-8000-00805f9b34fb (Handle: 21): PnP ID
# 		uuid: 00002a50-0000-1000-8000-00805f9b34fb
# 		description : PnP ID
# 		properties : ['read']
# 00001530-0000-3512-2118-0009af100700 (Handle: 23): Unknown
# 	uuid: 00001530-0000-3512-2118-0009af100700
# 	characteristic list:
# 		 00001531-0000-3512-2118-0009af100700 (Handle: 24): Unknown
# 		uuid: 00001531-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['write', 'notify']
# 		 00001532-0000-3512-2118-0009af100700 (Handle: 27): Unknown
# 		uuid: 00001532-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['write-without-response']
# 00001811-0000-1000-8000-00805f9b34fb (Handle: 29): Alert Notification Service
# 	uuid: 00001811-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a46-0000-1000-8000-00805f9b34fb (Handle: 30): New Alert
# 		uuid: 00002a46-0000-1000-8000-00805f9b34fb
# 		description : New Alert
# 		properties : ['write']
# 		 00002a44-0000-1000-8000-00805f9b34fb (Handle: 33): Alert Notification Control Point
# 		uuid: 00002a44-0000-1000-8000-00805f9b34fb
# 		description : Alert Notification Control Point
# 		properties : ['read', 'write', 'notify']
# 00001802-0000-1000-8000-00805f9b34fb (Handle: 36): Immediate Alert
# 	uuid: 00001802-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a06-0000-1000-8000-00805f9b34fb (Handle: 37): Alert Level
# 		uuid: 00002a06-0000-1000-8000-00805f9b34fb
# 		description : Alert Level
# 		properties : ['write-without-response']
# 0000180d-0000-1000-8000-00805f9b34fb (Handle: 39): Heart Rate
# 	uuid: 0000180d-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a37-0000-1000-8000-00805f9b34fb (Handle: 40): Heart Rate Measurement
# 		uuid: 00002a37-0000-1000-8000-00805f9b34fb
# 		description : Heart Rate Measurement
# 		properties : ['notify']
# 		 00002a39-0000-1000-8000-00805f9b34fb (Handle: 43): Heart Rate Control Point
# 		uuid: 00002a39-0000-1000-8000-00805f9b34fb
# 		description : Heart Rate Control Point
# 		properties : ['read', 'write']
# 0000fee0-0000-1000-8000-00805f9b34fb (Handle: 45): Anhui Huami Information Technology Co.
# 	uuid: 0000fee0-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00002a2b-0000-1000-8000-00805f9b34fb (Handle: 46): Current Time
# 		uuid: 00002a2b-0000-1000-8000-00805f9b34fb
# 		description : Current Time
# 		properties : ['read', 'write', 'notify']
# 		 00000001-0000-3512-2118-0009af100700 (Handle: 49): SDP
# 		uuid: 00000001-0000-3512-2118-0009af100700
# 		description : SDP
# 		properties : ['write-without-response', 'notify']
# 		 00000002-0000-3512-2118-0009af100700 (Handle: 52): Unknown
# 		uuid: 00000002-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['notify']
# 		 00000003-0000-3512-2118-0009af100700 (Handle: 55): RFCOMM
# 		uuid: 00000003-0000-3512-2118-0009af100700
# 		description : RFCOMM
# 		properties : ['write-without-response', 'notify']
# 		 00002a04-0000-1000-8000-00805f9b34fb (Handle: 58): Peripheral Preferred Connection Parameters
# 		uuid: 00002a04-0000-1000-8000-00805f9b34fb
# 		description : Peripheral Preferred Connection Parameters
# 		properties : ['read', 'write-without-response', 'notify']
# 		 00000004-0000-3512-2118-0009af100700 (Handle: 61): Unknown
# 		uuid: 00000004-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['write-without-response', 'notify']
# 		 00000005-0000-3512-2118-0009af100700 (Handle: 64): TCS-BIN
# 		uuid: 00000005-0000-3512-2118-0009af100700
# 		description : TCS-BIN
# 		properties : ['notify']
# 		 00000006-0000-3512-2118-0009af100700 (Handle: 67): Unknown
# 		uuid: 00000006-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['read', 'notify']
# 		 00000007-0000-3512-2118-0009af100700 (Handle: 70): ATT
# 		uuid: 00000007-0000-3512-2118-0009af100700
# 		description : ATT
# 		properties : ['read', 'notify']
# 		 00000008-0000-3512-2118-0009af100700 (Handle: 73): OBEX
# 		uuid: 00000008-0000-3512-2118-0009af100700
# 		description : OBEX
# 		properties : ['write', 'notify']
# 		 00000010-0000-3512-2118-0009af100700 (Handle: 76): UPNP
# 		uuid: 00000010-0000-3512-2118-0009af100700
# 		description : UPNP
# 		properties : ['notify']
# 		 00000020-0000-3512-2118-0009af100700 (Handle: 79): Unknown
# 		uuid: 00000020-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['read', 'write-without-response', 'notify']
# 		 0000000e-0000-3512-2118-0009af100700 (Handle: 82): Unknown
# 		uuid: 0000000e-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['write']
# 		 0000000f-0000-3512-2118-0009af100700 (Handle: 85): BNEP
# 		uuid: 0000000f-0000-3512-2118-0009af100700
# 		description : BNEP
# 		properties : ['write-without-response', 'notify']
# 0000fee1-0000-1000-8000-00805f9b34fb (Handle: 88): Anhui Huami Information Technology Co.
# 	uuid: 0000fee1-0000-1000-8000-00805f9b34fb
# 	characteristic list:
# 		 00000009-0000-3512-2118-0009af100700 (Handle: 89): Unknown
# 		uuid: 00000009-0000-3512-2118-0009af100700
# 		description : Unknown
# 		properties : ['read', 'write-without-response', 'notify']
# 		 0000fedd-0000-1000-8000-00805f9b34fb (Handle: 92): Jawbone
# 		uuid: 0000fedd-0000-1000-8000-00805f9b34fb
# 		description : Jawbone
# 		properties : ['write']
# 		 0000fede-0000-1000-8000-00805f9b34fb (Handle: 94): Coin: Inc.
# 		uuid: 0000fede-0000-1000-8000-00805f9b34fb
# 		description : Coin: Inc.
# 		properties : ['read']
# 		 0000fedf-0000-1000-8000-00805f9b34fb (Handle: 96): Design SHIFT
# 		uuid: 0000fedf-0000-1000-8000-00805f9b34fb
# 		description : Design SHIFT
# 		properties : ['read']
# 		 0000fed0-0000-1000-8000-00805f9b34fb (Handle: 98): Apple: Inc.
# 		uuid: 0000fed0-0000-1000-8000-00805f9b34fb
# 		description : Apple: Inc.
# 		properties : ['read', 'write']
# 		 0000fed1-0000-1000-8000-00805f9b34fb (Handle: 100): Apple: Inc.
# 		uuid: 0000fed1-0000-1000-8000-00805f9b34fb
# 		description : Apple: Inc.
# 		properties : ['read', 'write']
# 		 0000fed2-0000-1000-8000-00805f9b34fb (Handle: 102): Apple: Inc.
# 		uuid: 0000fed2-0000-1000-8000-00805f9b34fb
# 		description : Apple: Inc.
# 		properties : ['read']
# 		 0000fed3-0000-1000-8000-00805f9b34fb (Handle: 104): Apple: Inc.
# 		uuid: 0000fed3-0000-1000-8000-00805f9b34fb
# 		description : Apple: Inc.
# 		properties : ['read', 'write']
# 		 0000fec1-0000-3512-2118-0009af100700 (Handle: 106): KDDI Corporation
# 		uuid: 0000fec1-0000-3512-2118-0009af100700
# 		description : KDDI Corporation
# 		properties : ['read', 'write', 'notify']
# disconnect
# done

# %%
import asyncio
from bleak import BleakClient

address = "DB:15:C2:8A:93:DF"
# 읽기/쓰기용 캐릭터리스틱 uuid
notity_charcteristic_uuid = "00002a37-0000-1000-8000-00805f9b34fb"

def notify_callback(sender: int, data: bytearray):
    print('sender: ', sender, 'data: ', data)

async def run(address):              
    # BleakClient 클래스 생성 및 바로 연결 시작
    # address: ESP32 맥주소
    # timeout: 연결 제한 시간 5초가 넘어가면 더 이상 연결하지 말고 종료
    async with BleakClient(address, timeout=60.0) as client:                    
        # 연결을 성공함
        print('connected')
        # 연결된 BLE 장치의 서비스 요청
        services = await client.get_services()
        # 서비스들을 루프돌려 내부 캐릭터리스틱 정보 조회
        for service in services:
            print('service uuid:', service.uuid)
            # 각 서비스들에 있는 캐릭터리스틱을 루프 돌려 속성들 파악하기
            for characteristic in service.characteristics:
                print('  uuid:', characteristic.uuid)
                # handle 정보도 함께 확인
                print('  handle:', characteristic.handle) 
                print('  properties: ', characteristic.properties)
                # 캐릭터리스틱 UUID가 우리가 찾는 UUID인지 먼저 확인
                if characteristic.uuid == notity_charcteristic_uuid:  
                    # 우리가 찾던 UUID가 맞다면 
                    # 해당 캐릭터리스틱에 notify 속성이 있는지 확인
                    if 'notify' in characteristic.properties:
                        # notify 속성이 있다면 BLE 장치의 notify 속성을 
                        # 활성화 작업 후 notify_callback 함수 연결                        
                        print('try to activate notify.')
                        await client.start_notify(characteristic.uuid, notify_callback)

        # client 가 연결된 상태라면        
        if client.is_connected:
            # 1초간 대기
            await asyncio.sleep(1) 
            print('try to deactivate notify.')
            # 활성시켰단 notify를 중지 시킨다.
            await client.stop_notify(notity_charcteristic_uuid)

    #with 문을 빠져나오면 장치는 알아서 disconnect가 된다.
    print('disconnect')


loop = asyncio.get_event_loop()
loop.run_until_complete(run(address))
print('done')
# Out:
# connected
# service uuid: 00001800-0000-1000-8000-00805f9b34fb
#   uuid: 00002a00-0000-1000-8000-00805f9b34fb
#   handle: 2
#   properties:  ['read']
#   uuid: 00002a01-0000-1000-8000-00805f9b34fb
#   handle: 4
#   properties:  ['read']
#   uuid: 00002a04-0000-1000-8000-00805f9b34fb
#   handle: 6
#   properties:  ['read']
# service uuid: 00001801-0000-1000-8000-00805f9b34fb
#   uuid: 00002a05-0000-1000-8000-00805f9b34fb
#   handle: 9
#   properties:  ['read', 'indicate']
# service uuid: 0000180a-0000-1000-8000-00805f9b34fb
#   uuid: 00002a25-0000-1000-8000-00805f9b34fb
#   handle: 13
#   properties:  ['read']
#   uuid: 00002a27-0000-1000-8000-00805f9b34fb
#   handle: 15
#   properties:  ['read']
#   uuid: 00002a28-0000-1000-8000-00805f9b34fb
#   handle: 17
#   properties:  ['read']
#   uuid: 00002a23-0000-1000-8000-00805f9b34fb
#   handle: 19
#   properties:  ['read']
#   uuid: 00002a50-0000-1000-8000-00805f9b34fb
#   handle: 21
#   properties:  ['read']
# service uuid: 00001530-0000-3512-2118-0009af100700
#   uuid: 00001531-0000-3512-2118-0009af100700
#   handle: 24
#   properties:  ['write', 'notify']
#   uuid: 00001532-0000-3512-2118-0009af100700
#   handle: 27
#   properties:  ['write-without-response']
# service uuid: 00001811-0000-1000-8000-00805f9b34fb
#   uuid: 00002a46-0000-1000-8000-00805f9b34fb
#   handle: 30
#   properties:  ['write']
#   uuid: 00002a44-0000-1000-8000-00805f9b34fb
#   handle: 33
#   properties:  ['read', 'write', 'notify']
# service uuid: 00001802-0000-1000-8000-00805f9b34fb
#   uuid: 00002a06-0000-1000-8000-00805f9b34fb
#   handle: 37
#   properties:  ['write-without-response']
# service uuid: 0000180d-0000-1000-8000-00805f9b34fb
#   uuid: 00002a37-0000-1000-8000-00805f9b34fb
#   handle: 40
#   properties:  ['notify']
# try to activate notify.
# ---------------------------------------------------------------------------
# BleakDotNetTaskError                      Traceback (most recent call last)
# <ipython-input-11-5233b552e6cb> in <module>
#      50
#      51 loop = asyncio.get_event_loop()
# ---> 52 loop.run_until_complete(run(address))
#      53 print('done')
#
# ~\anaconda3\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      94                 raise RuntimeError(
#      95                     'Event loop stopped before Future completed.')
# ---> 96             return f.result()
#      97         finally:
#      98             events._set_running_loop(old_running_loop)
#
# ~\anaconda3\lib\asyncio\futures.py in result(self)
#     176         self.__log_traceback = False
#     177         if self._exception is not None:
# --> 178             raise self._exception
#     179         return self._result
#     180
#
# ~\anaconda3\lib\asyncio\tasks.py in __step(***failed resolving arguments***)
#     278                 # We use the `send` method directly, because coroutines
#     279                 # don't have `__iter__` and `__next__` methods.
# --> 280                 result = coro.send(None)
#     281             else:
#     282                 result = coro.throw(exc)
#
# <ipython-input-11-5233b552e6cb> in run(address)
#      35                         # 활성화 작업 후 notify_callback 함수 연결
#      36                         print('try to activate notify.')
# ---> 37                         await client.start_notify(characteristic.uuid, notify_callback)
#      38
#      39         # client 가 연결된 상태라면
#
# ~\anaconda3\lib\site-packages\bleak\backends\dotnet\client.py in start_notify(self, char_specifier, callback, **kwargs)
#     860         )
#     861
# --> 862         status = await wrap_IAsyncOperation(
#     863             IAsyncOperation[GattCommunicationStatus](
#     864                 characteristic_obj.WriteClientCharacteristicConfigurationDescriptorAsync(
#
# ~\anaconda3\lib\site-packages\bleak\backends\dotnet\utils.py in wrap_IAsyncOperation(op, return_type)
#      77         # Exception occurred. Wrap it in BleakDotNetTaskError
#      78         # to make it catchable.
# ---> 79         raise BleakDotNetTaskError(op.ErrorCode.ToString())
#      80     else:
#      81         # TODO: Handle IsCancelled.
#
# BleakDotNetTaskError: System.Exception: 특성을 쓸 수 없습니다. (예외가 발생한 HRESULT: 0x80650003)
